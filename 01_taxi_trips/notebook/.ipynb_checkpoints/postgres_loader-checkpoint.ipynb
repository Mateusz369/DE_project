# %%
url = "jdbc:postgresql://postgres:5432/postgres" 

properties = {
    "user": "postgres",
    "password": "postgres",
    "driver": "org.postgresql.Driver"
}

# %%
df.write.jdbc(
    url=url,
    table="green_taxi",   
    mode="overwrite",           
    properties=properties
)
